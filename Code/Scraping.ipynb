# %%
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import requests
import re
import pickle

# %% [markdown]
# ### Movie name & Consensus

# %%
def name_consensus_fn(soup):
    try:
        movie_name = soup.find('div',{'class':'mop-ratings-wrap score_panel js-mop-ratings-wrap'})
        movie_name = soup.findAll('h1',{'class':'mop-ratings-wrap__title mop-ratings-wrap__title--top'})[0].get_text()
    except:
        print("something wrong with movie name")
        movie_name = np.NaN
        
#     critic_consensus = soup.findAll('p',{'class':'mop-ratings-wrap__text mop-ratings-wrap__text--concensus'})[0].get_text()

    try:
        critic_consensus = soup.findAll('p',{'class':'mop-ratings-wrap__text mop-ratings-wrap__text--concensus'})[0].get_text()
    except:
        print("something wrong with critic_consensus")
        critic_consensus = np.NaN
    return movie_name, critic_consensus

# %% [markdown]
# ### Ratings

# %%
def critic_score_fn(critic):
    try:
        critic_score = critic.find('span',{'class':'mop-ratings-wrap__percentage'}).get_text()
    except AttributeError:
        critic_score = np.NaN
#     print(critic_score)
    return critic_score

# %%
def num_critics_fn(critic):
    try:
        num_critics = critic.find('small',{'class':'mop-ratings-wrap__text--small'}).get_text()
    except:
        print("something wrong with num_critics")
        num_critics = np.NaN
#     print(num_critics)
    return num_critics

# %%
def audience_score_fn(audience):
    try:
        audience_score = audience.find('span',{'class':'mop-ratings-wrap__percentage'}).get_text()
    except AttributeError:
        audience_score = np.NaN
#     print(audience_score)        
    return audience_score

# %%
def num_audience_fn(audience):
    try:
        num_audience = audience.find('strong',{'class':'mop-ratings-wrap__text--small'}).get_text()
    except:
        print("something wrong with audience")
        num_audience = np.NaN
#     print(num_audience)
    return num_audience

# %% [markdown]
# ### Movie info

# %%
def synopsis_fn(tables):
    try:
        synopsis = tables.findAll('div',{'class':'movie_synopsis clamp clamp-6 js-clamp'})[0].get_text()
    except:
        synopsis = np.NaN
#     print(synopsis)
    return synopsis

# %%
def movie_info_fn(movie_info_box):
    dict_data = {}

    for i in range(12):
        try:
            ii = movie_info_box[i].findAll('div',{'class':'meta-label subtle'})[0].get_text()
            dict_data[ii] = movie_info_box[i].find('div',{'class':'meta-value'}).get_text()
    #         print(synopsis[i].findAll('div',{'class':'meta-label subtle'})[0].get_text(), synopsis[i].find('div',{'class':'meta-value'}).get_text())
        except:
            continue
    return dict_data

# %% [markdown]
# def pg_fn(tables):
#     pg = tables.findAll('div',{'class':'meta-value'})[0].get_text()
#     return pg
#
# def genre_fn(small_box):
#     genre = small_box[1].find('div',{'class':'meta-value'}).get_text()
#     return genre
#
# def directors_fn(small_box):
#     directors = small_box[2].findAll('div',{'class':'meta-value'})[0].get_text()
#     return directors
#
# def written_by_fn(small_box):
#     written_by = small_box[3].findAll('div',{'class':'meta-value'})[0].get_text()
#     return written_by
#
# def release_date_fn(small_box):
#     release_date = small_box[4].findAll('div',{'class':'meta-value'})[0].get_text()
#     return release_date
#
# def run_time_fn(small_box):
#     run_time = small_box[7].findAll('div',{'class':'meta-value'})[0].get_text()
#
# def studio_fn(small_box):
#     try:
#         studio = small_box[8].findAll('div',{'class':'meta-value'})[0].get_text()
#     except IndexError:
#         studio = np.NaN
#     return studio

# %% [markdown]
# ### Cast

# %%
def list_celeb_names_fn(all_celebrities):
    top_5_celeb_names = []
    try:
        for i in range(5):
            top_5_celeb_names.append(all_celebrities[i].attrs['href'][11:])
    except IndexError:
        pass
    return top_5_celeb_names

# %%
def scrape_celeb_names_fn(soup):
    cast = soup.find('div',{'class':'castSection'})
    top_5_celeb_names = []
    try :
        all_celebs = cast.findAll('a',{'class':'pull-left'})
        top_5_celeb_names = list_celeb_names_fn(all_celebs)
        top_5_celeb_names = ", ".join(top_5_celeb_names)
    except AttributeError:
        pass
    return top_5_celeb_names

# %% [markdown]
# ### Critics review

# %%
def critic_line_url_sub_fn(critic_lines):
    url =[]
    critic_line =[]
    for i in range(20):
        try:
            url.append(critic_lines[i].attrs['cite'])
            critic_line.append(critic_lines[i].get_text())
        except:
            continue
    return critic_line, url

# %%
def critic_line_url_fn(soup):
    try:
        critic_lines = soup.findAll('div',{'class':'panel-body content_body'})[3]
        critic_lines = critic_lines.findAll('blockquote',{'class':'media-body quote_bubble__quote'})
        critic_line, critic_url = critic_line_url_sub_fn(critic_lines)
        critic_line, critic_url = ", ".join(critic_line), ", ".join(critic_url)
    except:
        critic_line = np.NaN
        critic_url = np.NaN
    return critic_line, critic_url

# %% [markdown]
# ### Audience review

# %%
def audience_line_sub_fn(audience_review):
    audience_line =[]
    for i in range(10):
        try:
            audience_line.append(audience_review.findAll('div',{'class':'mop-audience-reviews__review--comment clamp clamp-4 js-clamp'})[i].get_text())
        except:
            continue
    return audience_line

# %%
def audience_review_fn(soup):
    audience_review = soup.find('ul',{'class':'mop-audience-reviews__reviews-wrap clearfix'})
    audience_lines = audience_line_sub_fn(audience_review)
    audience_review = "".join(audience_lines)
    return(audience_review)

# %% [markdown]
# ### Quotes

# %%
def quotes_helper_fn(quotes_lines):
    quote_lines = quotes_lines[1::2]
    cleaned_quotes = []
    for line in quote_lines:
        try:
            line = str(line).replace('\n','')
            cleaned_quotes.append(re.search('<span>(.*)</span>',line).group(1))
        except:
            continue
    quotes = "".join(cleaned_quotes)
    return quotes

# %%
def quotes_fn(soup):
#     quotes_lines = [
    try:
        quotes_url = soup.findAll('div',{'class':'panel-body content_body'})[4]
        quotes_url = quotes_url.find('a',{'class':'unstyled articleLink fr'}).attrs['href']
        quotes_url = 'https://www.rottentomatoes.com' + quotes_url
        quotes_page = requests.get(quotes_url)
        quotes_page=bs(quotes_page.text)
        quotes_lines = quotes_page.findAll('div',{'class':'panel-body content_body'})[1]
        quotes_lines = quotes_lines.findAll('span')
        
    except:
        return np.NaN
    
    return quotes_helper_fn(quotes_lines)

# %% [markdown]
# ## 27 K movies list

# %%
# import pandas as pd
# import glob

# print(glob.glob('*.csv'))

# final_df = pd.DataFrame()
# list_moovies = ['dataminer_0 (2).csv',
#  'dataminer_10000 (2).csv',
#  'dataminer_20000 (1).csv',
#  'dataminer_30000 (1).csv',
#  'dataminer_40000.csv',
#  'dataminer_50000.csv']

# for i in list_moovies:
#     df = pd.read_csv(i)
#     df.columns = ['url','name']
#     print(df.tail(3))
#     final_df = final_df.append(df)
    
# final_df = final_df.dropna()
# final_df = final_df.iloc[308:]
# final_df = final_df[:-22]
# final_df.to_csv("27K_movies_url.csv",index=False)

# %% [markdown]
# ### Scraping to get movie names

# %%
# page = requests.get("https://www.rottentomatoes.com/top/bestofrt/top_100_action__adventure_movies/")
# soup=bs(page.text)

# all_genre_100 = soup.findAll('ul',{'class':'dropdown-menu'})
# little_cleaned_genre_100 = all_genre_100[0].findAll('a')

# links_100_movies_various_genre = []

# for i in range(17):
#     extension = str(little_cleaned_genre_100[i].attrs['href'])
#     extension = "https://www.rottentomatoes.com" + extension
#     links_100_movies_various_genre.append(extension)

# movie_url_genre = pd.DataFrame(columns=['url'])

# for i in links_100_movies_various_genre:
#     try:
# #         print(i)
#         movie_links_genre = pd.DataFrame()
#         page = requests.get(i)
#         soup=bs(page.text)

#         movie_genre = soup.find('button',{'class':'dropdown-toggle btn btn-primary-border fullWidth'}).get_text()
#         movie_genre = str(movie_genre).replace('\n','')
#         movie_genre = str(movie_genre).replace(' ','')
#         full_table = soup.find('table',{'class':'table'})
#     #     print(full_table)
#         movies_list_url = []
#         for i in range(100):
#             url_uncleaned = full_table.findAll('a',{'class':'unstyled articleLink'})[i].attrs['href']
#             url_cleaned = 'https://www.rottentomatoes.com' + url_uncleaned
#             movies_list_url.append(url_cleaned)

#     #     print(movies_list_url)

#         movie_links_genre = pd.DataFrame(movies_list_url, columns = ['url'])
#         movie_links_genre['genre'] =  movie_genre
#         movie_url_genre = movie_url_genre.append(movie_links_genre)  
#     except:
#         continue
        
# movie_url_genre.to_csv("movie_url_genre.csv", index=False)

# %%
movie_name_url_27k = pd.read_csv("27K_movies_url.csv")
movie_name_url_27k = movie_name_url_27k[~movie_name_url_27k.url.str.contains("/m/null")]
movie_name_url_27k = movie_name_url_27k[movie_name_url_27k.url.str.contains("/m")]
movie_name_url_27k = movie_name_url_27k[~movie_name_url_27k.url.str.contains("editorial")]
movie_name_url_27k['url'] = 'https://www.rottentomatoes.com' + movie_name_url_27k.url
movie_name_url_27k.head()
# Out:
#                                                  url  \
# 0        https://www.rottentomatoes.com/m/mulan_2020
# 1  https://www.rottentomatoes.com/m/bill_and_ted_...
# 2   https://www.rottentomatoes.com/m/i_hate_new_york
# 3         https://www.rottentomatoes.com/m/get_duked
# 4  https://www.rottentomatoes.com/m/the_garden_le...
#
#                                             name
# 0                       Mulan 76%Available Sep 4
# 1  Bill & Ted Face the Music 81%Available Aug 28
# 2            I Hate New York 100%Available Sep 1
# 3                 Get Duked! 86%Available Aug 28
# 4      The Garden Left Behind 92%Available Sep 8

# %%
movie_name_url_27k.shape
# Out:
# (26834, 2)

# %%
# movie_url_genre = pd.read_csv("movie_url_genre.csv")

# %%
def scrape_rotten(movies_list):
    final_df = pd.DataFrame()
    i=0
    for x in movies_list.url:
        try:

            print(x)
            print(i)
            i+=1
            page = requests.get(x)
            soup=bs(page.text)

            movie_name, critic_consensus = name_consensus_fn(soup)

            critic = soup.find('div',{'class':'mop-ratings-wrap__half'})
            critic_score = critic_score_fn(critic)
            num_critics = num_critics_fn(critic)

            audience = soup.find('div',{'class':'mop-ratings-wrap__half audience-score'})
            audience_score = audience_score_fn(audience)
            num_audience = num_audience_fn(audience)

            tables = soup.find('div',{'class':'panel-body content_body'})
            synopsis = synopsis_fn(tables)
    #         pg = pg_fn(tables)

            movie_info = tables.findAll('li',{'class':'meta-row clearfix'})
            movie_info_dict = movie_info_fn(movie_info)
    #         genre = genre_fn(small_box)
    #         directors = directors_fn(small_box)
    #         written_by = written_by_fn(small_box)
    #         release_date = release_date_fn(small_box)
    #         run_time = run_time_fn(small_box)
    #         print(run_time)
    #         studio = studio_fn(small_box)


            top_5_celeb_names = scrape_celeb_names_fn(soup)
            critic_line, critic_url = critic_line_url_fn(soup)
            audience_review = audience_review_fn(soup)
            quotes = quotes_fn(soup)


    #         print("=="*30)

            df=pd.DataFrame([movie_info_dict])
            df['movie_name'] = [movie_name]
            df['critic_consensus'] = critic_consensus

            df['critic_score'] = [critic_score]
            df['audience_score'] = [audience_score]
    #         df['pg'] = pg
    #         df['genre'] = genre
    #         df['directors'] = directors
    #         df['written_by'] = written_by
    #         df['release_date'] = release_date
    #         df['run_time'] = run_time
    #         df['studio'] = studio
            try:
                df['top_5_celeb_names'] = top_5_celeb_names
            except ValueError:
                df['top_5_celeb_names'] = np.NaN
            df['critic_line'] = critic_line
            df['critic_url'] = critic_url
            df['audience_review'] = audience_review
            df['quotes'] = quotes

            final_df = final_df.append(df)
        except:
            print(i)
            final_df.to_csv("27k_data.csv")
    return final_df

# %%
movies_27k_info = scrape_rotten(movie_name_url_27k)
movies_27k_info = movies_27k_info.replace('\n','', regex=True)
movies_27k_info = movies_27k_info.replace('  ','', regex=True)
movies_27k_info.to_csv('27k_data.csv',index=False)
movies_27k_info.to_pickle("27k_data.pkl")
# Out:
# https://www.rottentomatoes.com/m/hillsong_let_hope_rise
# 20000
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_disappointments_room
# 20001
# https://www.rottentomatoes.com/m/the_magnificent_seven_2016
# 20002
# https://www.rottentomatoes.com/m/snowden
# 20003
# https://www.rottentomatoes.com/m/when_the_bough_breaks_2016
# 20004
# https://www.rottentomatoes.com/m/storks
# 20005
# https://www.rottentomatoes.com/m/sully
# 20006
# https://www.rottentomatoes.com/m/hitchcocktruffaut
# 20007
# https://www.rottentomatoes.com/m/greater
# 20008
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/denial_2016
# 20009
# https://www.rottentomatoes.com/m/middle_school_the_worst_years_of_my_life
# 20010
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/31
# 20011
# https://www.rottentomatoes.com/m/operation_avalanche
# 20012
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_monkey_king_2
# 20013
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/american_honey
# 20014
# https://www.rottentomatoes.com/m/under_the_shadow
# 20015
# https://www.rottentomatoes.com/m/no_manches_frida
# 20016
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kill_command
# 20017
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_man_called_ove
# 20018
# https://www.rottentomatoes.com/m/in_a_valley_of_violence
# 20019
# https://www.rottentomatoes.com/m/coming_through_the_rye
# 20020
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/blair_witch
# 20021
# https://www.rottentomatoes.com/m/bright_lights_starring_carrie_fisher_and_debbie_reynolds
# 20022
# https://www.rottentomatoes.com/m/dog_eat_dog_2016
# 20023
# https://www.rottentomatoes.com/m/barry_2016
# 20024
# https://www.rottentomatoes.com/m/pet_2016
# 20025
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/it_had_to_be_you_2016
# 20026
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/jim_gaffigan_cinco
# 20027
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/phantasm
# 20028
# https://www.rottentomatoes.com/m/almayers_folly_2012
# 20029
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_secret_life_of_pets
# 20030
# https://www.rottentomatoes.com/m/odd_brodsky
# 20031
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_bfg_2016
# 20032
# https://www.rottentomatoes.com/m/yoga_hosers
# 20033
# https://www.rottentomatoes.com/m/mechanic_resurrection
# 20034
# https://www.rottentomatoes.com/m/dont_breathe_2016
# 20035
# https://www.rottentomatoes.com/m/kubo_and_the_two_strings_2016
# 20036
# https://www.rottentomatoes.com/m/petes_dragon_2016
# 20037
# https://www.rottentomatoes.com/m/war_dogs_2016
# 20038
# https://www.rottentomatoes.com/m/our_little_sister
# 20039
# https://www.rottentomatoes.com/m/heart_of_a_dog
# 20040
# https://www.rottentomatoes.com/m/mavis
# 20041
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lo_and_behold_reveries_of_the_connected_world
# 20042
# https://www.rottentomatoes.com/m/absolutely_fabulous_the_movie
# 20043
# https://www.rottentomatoes.com/m/kicks_2016
# 20044
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_wild_life
# 20045
# https://www.rottentomatoes.com/m/hands_of_stone
# 20046
# https://www.rottentomatoes.com/m/dont_think_twice
# 20047
# https://www.rottentomatoes.com/m/hell_or_high_water
# 20048
# https://www.rottentomatoes.com/m/divines
# 20049
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/good_kids_2016
# 20050
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/be_my_cat_a_film_for_anne
# 20051
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/it_2016
# 20052
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ordinary_world_2016
# 20053
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_possession_experiment
# 20054
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_24_hour_war
# 20055
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/esteros_2016
# 20056
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/run_the_tide_2016
# 20057
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/marathon_the_patriots_day_bombing_2016
# 20058
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/michael_che_matters
# 20059
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/finding_dory
# 20060
# https://www.rottentomatoes.com/m/star_trek_beyond
# 20061
# https://www.rottentomatoes.com/m/sausage_party
# 20062
# https://www.rottentomatoes.com/m/fort_tilden
# 20063
# https://www.rottentomatoes.com/m/my_love_dont_cross_that_river
# 20064
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/deep_web
# 20065
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mia_madre
# 20066
# https://www.rottentomatoes.com/m/the_sea_of_trees
# 20067
# https://www.rottentomatoes.com/m/nine_lives_2016
# 20068
# https://www.rottentomatoes.com/m/uncle_kent_2
# 20069
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/band_of_robbers_2016
# 20070
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_similars
# 20071
# https://www.rottentomatoes.com/m/christmas_eve_2015
# 20072
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lucha_mexico
# 20073
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/uncle_nick_2015
# 20074
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/miltons_secret
# 20075
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/imperium
# 20076
# https://www.rottentomatoes.com/m/indignation
# 20077
# https://www.rottentomatoes.com/m/gleason_2016
# 20078
# https://www.rottentomatoes.com/m/bad_moms
# 20079
# https://www.rottentomatoes.com/m/kickboxer_vengeance
# 20080
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/tikkun_2016
# 20081
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_true_memoirs_of_an_international_assassin_2016
# 20082
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lazy_eye
# 20083
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/anthropoid
# 20084
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/cardboard_boxer
# 20085
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/operator_2016
# 20086
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/life_on_the_line_2016
# 20087
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/my_dead_boyfriend
# 20088
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/blue_jay
# 20089
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_ivory_game
# 20090
# https://www.rottentomatoes.com/m/army_of_one_2016
# 20091
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/little-fauss-and-big-halsy
# 20092
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/jianyu_2010
# 20093
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_lost_bladesman
# 20094
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/bayou_maharajah
# 20095
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/independence_day_resurgence
# 20096
# https://www.rottentomatoes.com/m/alice_in_wonderland_through_the_looking_glass
# 20097
# https://www.rottentomatoes.com/m/schneider_vs_bax
# 20098
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/skiptrace
# 20099
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_beat_beneath_my_feet
# 20100
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/cafe_society_2016
# 20101
# https://www.rottentomatoes.com/m/captain_fantastic
# 20102
# https://www.rottentomatoes.com/m/lights_out_2016
# 20103
# https://www.rottentomatoes.com/m/our_kind_of_traitor_2016
# 20104
# https://www.rottentomatoes.com/m/the_apostate_2016
# 20105
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/norman_lear_just_another_version_of_you
# 20106
# https://www.rottentomatoes.com/m/whos_driving_doug
# 20107
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sky_ladder_the_art_of_cai_guo_qiang_2016
# 20108
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/nerve_2016
# 20109
# https://www.rottentomatoes.com/m/papa_hemingway_in_cuba
# 20110
# https://www.rottentomatoes.com/m/we_the_people_the_market_basket_effect
# 20111
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/fear_inc
# 20112
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/jack_goes_home
# 20113
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mr_church
# 20114
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/front_cover_2016
# 20115
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/spaceman_2016
# 20116
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/autumn_lights
# 20117
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/into_the_inferno
# 20118
# https://www.rottentomatoes.com/m/batman_return_of_the_caped_crusaders
# 20119
# https://www.rottentomatoes.com/m/the_windmill_2016
# 20120
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/i_am_the_pretty_thing_that_lives_in_the_house
# 20121
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_haunting_of_briar_house
# 20122
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/orange_sunshine_2016
# 20123
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ghostbusters_2016
# 20124
# https://www.rottentomatoes.com/m/x_men_apocalypse
# 20125
# https://www.rottentomatoes.com/m/ice_age_collision_course
# 20126
# https://www.rottentomatoes.com/m/the_legend_of_tarzan
# 20127
# https://www.rottentomatoes.com/m/the_infiltrator
# 20128
# https://www.rottentomatoes.com/m/the_purge_election_year
# 20129
# https://www.rottentomatoes.com/m/the_siege_of_jadotville
# 20130
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/breaking_a_monster
# 20131
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sherpa
# 20132
# https://www.rottentomatoes.com/m/mascots
# 20133
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/len_and_company
# 20134
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/blinky_bill_the_movie
# 20135
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/into_the_forest
# 20136
# https://www.rottentomatoes.com/m/the_minds_eye_2016
# 20137
# https://www.rottentomatoes.com/m/the_demolisher
# 20138
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ithaca
# 20139
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/complete_unknown
# 20140
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/life_animated
# 20141
# https://www.rottentomatoes.com/m/swiss_army_man
# 20142
# https://www.rottentomatoes.com/m/joshy
# 20143
# https://www.rottentomatoes.com/m/chicken_people
# 20144
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_late_bloomer_2016
# 20145
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sharknado_the_4th_awakens
# 20146
# https://www.rottentomatoes.com/m/blood_father
# 20147
# https://www.rottentomatoes.com/m/approaching_the_unknown
# 20148
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_wailing
# 20149
# https://www.rottentomatoes.com/m/hillarys_america_the_secret_history_of_the_democratic_party
# 20150
# https://www.rottentomatoes.com/m/the_hollow
# 20151
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kingsglaive_final_fantasy_xv_2016
# 20152
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ovation
# 20153
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/london_town_2016
# 20154
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/justin_timberlake_the_tennessee_kids
# 20155
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1003757-cat_people
# 20156
# https://www.rottentomatoes.com/m/warcraft
# 20157
# https://www.rottentomatoes.com/m/cell_2016
# 20158
# https://www.rottentomatoes.com/m/teenage_mutant_ninja_turtles_out_of_the_shadows
# 20159
# https://www.rottentomatoes.com/m/the_president_2016
# 20160
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/central_intelligence
# 20161
# https://www.rottentomatoes.com/m/mike_and_dave_need_wedding_dates
# 20162
# https://www.rottentomatoes.com/m/city_of_gold_2016
# 20163
# https://www.rottentomatoes.com/m/neighbors_2_sorority_rising
# 20164
# https://www.rottentomatoes.com/m/free_state_of_jones
# 20165
# https://www.rottentomatoes.com/m/the_neon_demon
# 20166
# https://www.rottentomatoes.com/m/danny_says
# 20167
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/they_will_have_to_kill_us_first
# 20168
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_shallows
# 20169
# https://www.rottentomatoes.com/m/colliding_dreams
# 20170
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/audrie_and_daisy
# 20171
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/goat_2016
# 20172
# https://www.rottentomatoes.com/m/hunt_for_the_wilderpeople
# 20173
# https://www.rottentomatoes.com/m/eat_that_question_frank_zappa_in_his_own_words
# 20174
# https://www.rottentomatoes.com/m/under_the_sun_2016
# 20175
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_lovers_and_the_despot
# 20176
# https://www.rottentomatoes.com/m/transpecos
# 20177
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/my_blind_brother
# 20178
# https://www.rottentomatoes.com/m/the_good_neighbor_2016
# 20179
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/finding_altamira
# 20180
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_beatles_eight_days_a_week_the_touring_years
# 20181
# https://www.rottentomatoes.com/m/dancer_2016
# 20182
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/amanda_knox
# 20183
# https://www.rottentomatoes.com/m/clowntown_2016
# 20184
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/flock_of_dudes_2016
# 20185
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/everlasting
# 20186
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/chimes_at_midnight_1965
# 20187
# https://www.rottentomatoes.com/m/tell_me_that_you_love_me_junie_moon
# 20188
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/indigo_children
# 20189
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_angry_birds_movie
# 20190
# https://www.rottentomatoes.com/m/clown_2016
# 20191
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_jungle_book_2016
# 20192
# https://www.rottentomatoes.com/m/ratchet_and_clank
# 20193
# https://www.rottentomatoes.com/m/the_nice_guys
# 20194
# https://www.rottentomatoes.com/m/me_before_you
# 20195
# https://www.rottentomatoes.com/m/the_huntsman_winters_war
# 20196
# https://www.rottentomatoes.com/m/what_happened_miss_simone_2015
# 20197
# https://www.rottentomatoes.com/m/gods_not_dead_2
# 20198
# https://www.rottentomatoes.com/m/wiener_dog
# 20199
# https://www.rottentomatoes.com/m/beautiful_something
# 20200
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/downriver
# 20201
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/disorder_2016
# 20202
# https://www.rottentomatoes.com/m/the_man_who_knew_infinity
# 20203
# https://www.rottentomatoes.com/m/sunset_song
# 20204
# https://www.rottentomatoes.com/m/11_minutes
# 20205
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/klown_forever
# 20206
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/maggies_plan_2016
# 20207
# https://www.rottentomatoes.com/m/the_intervention
# 20208
# https://www.rottentomatoes.com/m/weiner
# 20209
# https://www.rottentomatoes.com/m/jane_wants_a_boyfriend
# 20210
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/i_am_not_a_serial_killer
# 20211
# https://www.rottentomatoes.com/m/sundown_2016
# 20212
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/billionaire_ransom
# 20213
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/citizen_soldier_2016
# 20214
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/xoxo_2016
# 20215
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ace_the_case_manhattan_mystery_2016
# 20216
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/floyd_norman_an_animated_life
# 20217
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kampai_for_the_love_of_sake
# 20218
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_story_of_the_last_chrysanthemums
# 20219
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/now_you_see_me_2
# 20220
# https://www.rottentomatoes.com/m/the_conjuring_2
# 20221
# https://www.rottentomatoes.com/m/captain_america_civil_war
# 20222
# https://www.rottentomatoes.com/m/misconception
# 20223
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hockney
# 20224
# https://www.rottentomatoes.com/m/equals_2016
# 20225
# https://www.rottentomatoes.com/m/take_me_to_the_river_2016
# 20226
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/popstar_never_stop_never_stopping
# 20227
# https://www.rottentomatoes.com/m/the_seventh_fire
# 20228
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/money_monster
# 20229
# https://www.rottentomatoes.com/m/a_bigger_splash_2016
# 20230
# https://www.rottentomatoes.com/m/neon_bull
# 20231
# https://www.rottentomatoes.com/m/the_ones_below
# 20232
# https://www.rottentomatoes.com/m/presenting_princess_shaw
# 20233
# https://www.rottentomatoes.com/m/night_of_the_living_deb
# 20234
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_automatic_hate
# 20235
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/all_the_way_2016
# 20236
# https://www.rottentomatoes.com/m/the_meddler_2016
# 20237
# https://www.rottentomatoes.com/m/compadres_2016
# 20238
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/genius_2016
# 20239
# https://www.rottentomatoes.com/m/the_darkness
# 20240
# https://www.rottentomatoes.com/m/the_fits_2016
# 20241
# https://www.rottentomatoes.com/m/love_and_friendship
# 20242
# https://www.rottentomatoes.com/m/vaxxed_from_cover_up_to_catastrophe_2016
# 20243
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/marauders_2016
# 20244
# https://www.rottentomatoes.com/m/buddymoon
# 20245
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/brother_nature
# 20246
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_neighbor_2016
# 20247
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_white_helmets
# 20248
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/arq
# 20249
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/moments_of_clarity
# 20250
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/tricked_2016
# 20251
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/batman_v_superman_dawn_of_justice
# 20252
# https://www.rottentomatoes.com/m/monster_hunt
# 20253
# https://www.rottentomatoes.com/m/i_am_wrath
# 20254
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/criminal_2016
# 20255
# https://www.rottentomatoes.com/m/listening_2014
# 20256
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_boss_2016
# 20257
# https://www.rottentomatoes.com/m/the_russian_woodpecker
# 20258
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/barbershop_the_next_cut_2016
# 20259
# https://www.rottentomatoes.com/m/demolition_2016
# 20260
# https://www.rottentomatoes.com/m/enemy_territory_2016
# 20261
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/born_to_be_blue
# 20262
# https://www.rottentomatoes.com/m/hardcore_henry
# 20263
# https://www.rottentomatoes.com/m/born_to_dance_2015
# 20264
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/river_2016
# 20265
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/high_rise_2016
# 20266
# https://www.rottentomatoes.com/m/elvis_and_nixon_2016
# 20267
# https://www.rottentomatoes.com/m/the_childhood_of_a_leader
# 20268
# https://www.rottentomatoes.com/m/viral_2016
# 20269
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/bite_2016
# 20270
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/miles_ahead_2016
# 20271
# https://www.rottentomatoes.com/m/sing_street
# 20272
# https://www.rottentomatoes.com/m/tallulah
# 20273
# https://www.rottentomatoes.com/m/the_perfect_match_2016
# 20274
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/quitters_2016
# 20275
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/most_likely_to_die
# 20276
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_american_side
# 20277
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ghost_team_2016
# 20278
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/edge_of_winter
# 20279
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/undrafted_2016
# 20280
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ants_on_a_shrimp
# 20281
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_hologram_for_the_king
# 20282
# https://www.rottentomatoes.com/m/little_white_lie
# 20283
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sea_fog
# 20284
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_bronze
# 20285
# https://www.rottentomatoes.com/m/last_days_in_the_desert
# 20286
# https://www.rottentomatoes.com/m/songs_my_brothers_taught_me
# 20287
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lazer_team
# 20288
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/summer_camp_2016
# 20289
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sun_choke
# 20290
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/louder_than_bombs_2016
# 20291
# https://www.rottentomatoes.com/m/april_and_the_extraordinary_world_2016
# 20292
# https://www.rottentomatoes.com/m/keanu_2016
# 20293
# https://www.rottentomatoes.com/m/requiem_for_the_american_dream
# 20294
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/confirmation
# 20295
# https://www.rottentomatoes.com/m/the_lobster
# 20296
# https://www.rottentomatoes.com/m/holding_the_man
# 20297
# https://www.rottentomatoes.com/m/mothers_day_2016
# 20298
# https://www.rottentomatoes.com/m/parched
# 20299
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/fathers_and_daughters
# 20300
# https://www.rottentomatoes.com/m/five_nights_in_maine
# 20301
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/meet_the_blacks
# 20302
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/richard_linklater_dream_is_destiny
# 20303
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_land_2016
# 20304
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/high_strung_2016
# 20305
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_first_monday_in_may
# 20306
# https://www.rottentomatoes.com/m/the_trust_2016
# 20307
# https://www.rottentomatoes.com/m/batman_the_killing_joke
# 20308
# https://www.rottentomatoes.com/m/traded
# 20309
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/can_we_take_a_joke_2016
# 20310
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/gernika
# 20311
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/david_cross_making_america_great_again
# 20312
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/term_life
# 20313
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/search_party
# 20314
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/boy_and_the_world
# 20315
# https://www.rottentomatoes.com/m/the_divergent_series_allegiant
# 20316
# https://www.rottentomatoes.com/m/the_dark_horse_2016
# 20317
# https://www.rottentomatoes.com/m/everybody_wants_some
# 20318
# https://www.rottentomatoes.com/m/circle_2015
# 20319
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/green_room_2016
# 20320
# https://www.rottentomatoes.com/m/miracles_from_heaven
# 20321
# https://www.rottentomatoes.com/m/by_the_sea_2015
# 20322
# https://www.rottentomatoes.com/m/i_saw_the_light
# 20323
# https://www.rottentomatoes.com/m/my_golden_days
# 20324
# https://www.rottentomatoes.com/m/600_miles
# 20325
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_sinner_in_mecca
# 20326
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_adderall_diaries
# 20327
# https://www.rottentomatoes.com/m/the_debt_2016
# 20328
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/my_big_night_2016
# 20329
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_family_fang
# 20330
# https://www.rottentomatoes.com/m/no_men_beyond_this_point
# 20331
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_dresser
# 20332
# https://www.rottentomatoes.com/m/mountains_may_depart_2016
# 20333
# https://www.rottentomatoes.com/m/outlaws_and_angels
# 20334
# https://www.rottentomatoes.com/m/mei_ren_yu
# 20335
# https://www.rottentomatoes.com/m/brahman_naman
# 20336
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/13_cameras
# 20337
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/bling_2016
# 20338
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/holidays
# 20339
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mad_tiger
# 20340
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/free_to_run
# 20341
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_dog_lover
# 20342
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/vigilante_diaries
# 20343
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/andron
# 20344
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/knight_of_cups
# 20345
# https://www.rottentomatoes.com/m/ray_harryhausen_special_effects_titan
# 20346
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kung_fu_panda_3
# 20347
# https://www.rottentomatoes.com/m/stand_clear_of_the_closing_doors
# 20348
# https://www.rottentomatoes.com/m/the_keeper_of_lost_causes
# 20349
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/midnight_special_2015
# 20350
# https://www.rottentomatoes.com/m/whiskey_tango_foxtrot
# 20351
# https://www.rottentomatoes.com/m/my_big_fat_greek_wedding_2
# 20352
# https://www.rottentomatoes.com/m/lucky_stiff_2015
# 20353
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/adventures_in_babysitting_2015
# 20354
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/raiders_the_story_of_the_greatest_fan_film_ever_made
# 20355
# https://www.rottentomatoes.com/m/roseanne_for_president
# 20356
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/fastball
# 20357
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_absent_one
# 20358
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/eye_in_the_sky
# 20359
# https://www.rottentomatoes.com/m/the_girl_in_the_photographs
# 20360
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_wave_2016
# 20361
# https://www.rottentomatoes.com/m/embrace_of_the_serpent
# 20362
# https://www.rottentomatoes.com/m/the_steps
# 20363
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_brothers_grimsby
# 20364
# https://www.rottentomatoes.com/m/francofonia
# 20365
# https://www.rottentomatoes.com/m/rabin_the_last_day
# 20366
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/carnage_park
# 20367
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_fundamentals_of_caring
# 20368
# https://www.rottentomatoes.com/m/precious_cargo_2016
# 20369
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_conspiracy_of_faith_2016
# 20370
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_last_king_2016
# 20371
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_phenom_2016
# 20372
# https://www.rottentomatoes.com/m/the_duel_2016
# 20373
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/out_of_print_2016
# 20374
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/intruder_2016
# 20375
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hail_caesar_2016
# 20376
# https://www.rottentomatoes.com/m/careful_what_you_wish_for
# 20377
# https://www.rottentomatoes.com/m/the_young_messiah
# 20378
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/zootopia
# 20379
# https://www.rottentomatoes.com/m/altered_minds_2015
# 20380
# something wrong with movie name
# something wrong with critic_consensus
# something wrong with num_critics
# something wrong with audience
# 20381
# https://www.rottentomatoes.com/m/london_has_fallen
# 20381
# https://www.rottentomatoes.com/m/kill_your_friends
# 20382
# https://www.rottentomatoes.com/m/seve_the_movie
# 20383
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/another
# 20384
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/eddie_the_eagle
# 20385
# https://www.rottentomatoes.com/m/every_thing_will_be_fine
# 20386
# https://www.rottentomatoes.com/m/one_more_time_2016
# 20387
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hello_my_name_is_doris
# 20388
# https://www.rottentomatoes.com/m/those_people_2016
# 20389
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/puerto_ricans_in_paris
# 20390
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/king_jack
# 20391
# https://www.rottentomatoes.com/m/13_hours_the_secret_soldiers_of_benghazi
# 20392
# https://www.rottentomatoes.com/m/anomalisa
# 20393
# https://www.rottentomatoes.com/m/mr_right_2016
# 20394
# https://www.rottentomatoes.com/m/colonia
# 20395
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_boy_and_the_beast
# 20396
# https://www.rottentomatoes.com/m/the_other_side_of_the_door
# 20397
# https://www.rottentomatoes.com/m/touched_with_fire_2016
# 20398
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_funhouse_massacre
# 20399
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_war
# 20400
# https://www.rottentomatoes.com/m/busco_novio_para_mi_mujer
# 20401
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_abandoned_2016
# 20402
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/10_cloverfield_lane
# 20403
# https://www.rottentomatoes.com/m/the_confirmation_2016
# 20404
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/get_a_job_2016
# 20405
# https://www.rottentomatoes.com/m/blackway
# 20406
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_naked_island
# 20407
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_golden_dream
# 20408
# https://www.rottentomatoes.com/m/pride_and_prejudice_and_zombies
# 20409
# https://www.rottentomatoes.com/m/the_finest_hours
# 20410
# https://www.rottentomatoes.com/m/no_no_a_dockumentary
# 20411
# https://www.rottentomatoes.com/m/gods_of_egypt
# 20412
# https://www.rottentomatoes.com/m/race_2016
# 20413
# https://www.rottentomatoes.com/m/triple_9
# 20414
# https://www.rottentomatoes.com/m/how_to_be_single_2016
# 20415
# https://www.rottentomatoes.com/m/the_winding_stream_2014
# 20416
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/theeb
# 20417
# https://www.rottentomatoes.com/m/dirty_grandpa
# 20418
# https://www.rottentomatoes.com/m/helicopter_mom
# 20419
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_witch_2016
# 20420
# https://www.rottentomatoes.com/m/the_damned_dont_you_wish_that_we_were_dead
# 20421
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/zoolander_2
# 20422
# https://www.rottentomatoes.com/m/risen_2016
# 20423
# https://www.rottentomatoes.com/m/rise_of_the_legend_2014
# 20424
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_perfect_day
# 20425
# https://www.rottentomatoes.com/m/southbound
# 20426
# https://www.rottentomatoes.com/m/darling_2016
# 20427
# https://www.rottentomatoes.com/m/crush_the_skull
# 20428
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_curse_of_sleeping_beauty
# 20429
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/under_the_gun_2016
# 20430
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kindergarten_cop_2
# 20431
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/manhattan_night
# 20432
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/memoria_2016
# 20433
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/urge
# 20434
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hard_sell
# 20435
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/bo_burnham_make_happy
# 20436
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/pele_birth_of_a_legend_2016
# 20437
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/east_side_sushi
# 20438
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/regression
# 20439
# https://www.rottentomatoes.com/m/ride_along_2
# 20440
# https://www.rottentomatoes.com/m/joy_2014
# 20441
# https://www.rottentomatoes.com/m/the_fifth_wave
# 20442
# https://www.rottentomatoes.com/m/deadpool
# 20443
# https://www.rottentomatoes.com/m/bill_2016
# 20444
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_choice
# 20445
# https://www.rottentomatoes.com/m/a_royal_night_out
# 20446
# https://www.rottentomatoes.com/m/glassland
# 20447
# https://www.rottentomatoes.com/m/the_boy
# 20448
# https://www.rottentomatoes.com/m/creative_control
# 20449
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/bikes_vs_cars
# 20450
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/emelie
# 20451
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/dolly_partons_coat_of_many_colors
# 20452
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kill_zone_2_2016
# 20453
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mothers_and_daughters_2016
# 20454
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/eisenstein_in_guanajuato
# 20455
# https://www.rottentomatoes.com/m/synchronicity_2016
# 20456
# https://www.rottentomatoes.com/m/remember_2016
# 20457
# https://www.rottentomatoes.com/m/jack_of_the_red_hearts
# 20458
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/manson_family_vacation
# 20459
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/where_to_invade_next
# 20460
# https://www.rottentomatoes.com/m/janis_little_girl_blue
# 20461
# https://www.rottentomatoes.com/m/the_messenger_2015
# 20462
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/submerged_2015
# 20463
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mojin_the_lost_legend
# 20464
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/400_days
# 20465
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/elstree_1976
# 20466
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/special_correspondents
# 20467
# https://www.rottentomatoes.com/m/ali_wong_baby_cobra
# 20468
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/jane_got_a_gun
# 20469
# https://www.rottentomatoes.com/m/the_invitation
# 20470
# https://www.rottentomatoes.com/m/norm_of_the_north
# 20471
# https://www.rottentomatoes.com/m/the_revenant_2015
# 20472
# https://www.rottentomatoes.com/m/the_forest_2016
# 20473
# https://www.rottentomatoes.com/m/krampus
# 20474
# https://www.rottentomatoes.com/m/phoenix_2015
# 20475
# https://www.rottentomatoes.com/m/the_last_man_on_the_moon
# 20476
# https://www.rottentomatoes.com/m/the_lady_in_the_van
# 20477
# https://www.rottentomatoes.com/m/sembene_2015
# 20478
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/la_dame_dans_lauto_avec_un_fusil_et_des_lunettes
# 20479
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/drunk_stoned_brilliant_dead_the_story_of_the_national_lampoon
# 20480
# https://www.rottentomatoes.com/m/theory_of_obscurity_a_film_about_the_residents
# 20481
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ip_man_3
# 20482
# https://www.rottentomatoes.com/m/tale_of_tales
# 20483
# https://www.rottentomatoes.com/m/fifty_shades_of_black
# 20484
# https://www.rottentomatoes.com/m/6_years_2015
# 20485
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mustang_2015
# 20486
# https://www.rottentomatoes.com/m/sky_2016
# 20487
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/havana_motor_club
# 20488
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/horror_2015
# 20489
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/all_mistakes_buried
# 20490
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lamb_2016
# 20491
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/standoff_2016
# 20492
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/misconduct
# 20493
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/crazy_about_tiffanys
# 20494
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/about_scout_2016
# 20495
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hostile_border
# 20496
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hush_2016
# 20497
# https://www.rottentomatoes.com/m/patton_oswalt_talking_for_clapping
# 20498
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_brighter_summer_day_1991
# 20499
# https://www.rottentomatoes.com/m/rhythm_n_bayous_a_road_map_to_louisiana_music_2000
# 20500
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/point_break_2013
# 20501
# https://www.rottentomatoes.com/m/star_wars_episode_vii_the_force_awakens
# 20502
# https://www.rottentomatoes.com/m/the_nightingale_2015
# 20503
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_hateful_eight
# 20504
# https://www.rottentomatoes.com/m/patricks_day
# 20505
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/creep_2014
# 20506
# https://www.rottentomatoes.com/m/of_men_and_war
# 20507
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/cartel_land
# 20508
# https://www.rottentomatoes.com/m/the_hallow
# 20509
# https://www.rottentomatoes.com/m/how_to_change_the_world
# 20510
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/james_white
# 20511
# https://www.rottentomatoes.com/m/concussion_2015
# 20512
# https://www.rottentomatoes.com/m/a_poem_is_a_naked_person
# 20513
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/dixieland
# 20514
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/killing_them_safely_2015
# 20515
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_masked_saint
# 20516
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/veteran_2015
# 20517
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mojave_2016
# 20518
# https://www.rottentomatoes.com/m/cherry_tree
# 20519
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mediterranea_2015
# 20520
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/baskin
# 20521
# https://www.rottentomatoes.com/m/forsaken_2016
# 20522
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/dreams_rewired
# 20523
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/tumbledown_2016
# 20524
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/codegirl_2015
# 20525
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/anguish_2015
# 20526
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/avas_possessions
# 20527
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/exposed_2016
# 20528
# https://www.rottentomatoes.com/m/bleed_2016
# 20529
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/theyre_watching
# 20530
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_decline_of_western_civilization_1988
# 20531
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/decline_of_western_civilization_pt_2_the_the_metal_years
# 20532
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/addiction_incorporated
# 20533
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sisters_2015
# 20534
# https://www.rottentomatoes.com/m/the_hunger_games_mockingjay_part_2
# 20535
# https://www.rottentomatoes.com/m/the_peanuts_movie
# 20536
# https://www.rottentomatoes.com/m/victor_frankenstein_2015
# 20537
# https://www.rottentomatoes.com/m/in_the_heart_of_the_sea
# 20538
# https://www.rottentomatoes.com/m/alvin_and_the_chipmunks_the_road_chip
# 20539
# https://www.rottentomatoes.com/m/brooklyn
# 20540
# https://www.rottentomatoes.com/m/we_come_as_friends
# 20541
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/break_point
# 20542
# https://www.rottentomatoes.com/m/the_big_short
# 20543
# https://www.rottentomatoes.com/m/macbeth_2015
# 20544
# https://www.rottentomatoes.com/m/the_tribe_2015
# 20545
# https://www.rottentomatoes.com/m/carol
# 20546
# https://www.rottentomatoes.com/m/the_mask_you_live_in_2015
# 20547
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/steve_jobs_man_in_the_machine
# 20548
# https://www.rottentomatoes.com/m/the_benefactor
# 20549
# https://www.rottentomatoes.com/m/grease_live
# 20550
# https://www.rottentomatoes.com/m/love_2015
# 20551
# https://www.rottentomatoes.com/m/victoria_2015
# 20552
# https://www.rottentomatoes.com/m/the_program
# 20553
# https://www.rottentomatoes.com/m/mountain_men_2016
# 20554
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/what_our_fathers_did_a_nazi_legacy
# 20555
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hyena_road
# 20556
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/road_games_2015
# 20557
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/noma_my_perfect_storm
# 20558
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_preppie_connection_2016
# 20559
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_brainwashing_of_my_dad
# 20560
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1982_2013
# 20561
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_night_before_2015
# 20562
# https://www.rottentomatoes.com/m/sunshine_superman
# 20563
# https://www.rottentomatoes.com/m/noble_2014
# 20564
# https://www.rottentomatoes.com/m/the_forbidden_room_2015
# 20565
# https://www.rottentomatoes.com/m/i_smile_back
# 20566
# https://www.rottentomatoes.com/m/don_verdean
# 20567
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/creed_2015
# 20568
# https://www.rottentomatoes.com/m/jafar_panahis_taxi
# 20569
# https://www.rottentomatoes.com/m/secret_in_their_eyes_2015
# 20570
# https://www.rottentomatoes.com/m/legend_2015
# 20571
# https://www.rottentomatoes.com/m/the_danish_girl_2015
# 20572
# https://www.rottentomatoes.com/m/king_georges
# 20573
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/miss_you_already
# 20574
# https://www.rottentomatoes.com/m/gored
# 20575
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/youth_2015
# 20576
# something wrong with movie name
# something wrong with critic_consensus
# something wrong with num_critics
# something wrong with audience
# 20577
# https://www.rottentomatoes.com/m/narcopolis
# 20577
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/room_2015
# 20578
# https://www.rottentomatoes.com/m/ratter
# 20579
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lost_in_hong_kong
# 20580
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a_country_called_home
# 20581
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/yosemite_2016
# 20582
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/diablo_2016
# 20583
# https://www.rottentomatoes.com/m/capture_the_flag_2016
# 20584
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/moonwalkers_2016
# 20585
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_girl_in_the_book
# 20586
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/all_roads_lead_to_rome_2008
# 20587
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/intruders_2016
# 20588
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/marguerite_and_julien
# 20589
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_good_dinosaur
# 20590
# https://www.rottentomatoes.com/m/crimson_peak
# 20591
# https://www.rottentomatoes.com/m/the_33
# 20592
# https://www.rottentomatoes.com/m/spectre_2015
# 20593
# https://www.rottentomatoes.com/m/rock_the_kasbah
# 20594
# https://www.rottentomatoes.com/m/take_me_to_the_river_2014
# 20595
# https://www.rottentomatoes.com/m/entertainment
# 20596
# https://www.rottentomatoes.com/m/99_homes
# 20597
# https://www.rottentomatoes.com/m/second_coming_2014
# 20598
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/songs_from_the_north
# 20599
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/mi_5_2015
# 20600
# https://www.rottentomatoes.com/m/the_black_panthers_vanguard_of_the_revolution_2015
# 20601
# https://www.rottentomatoes.com/m/grandma_2015
# 20602
# https://www.rottentomatoes.com/m/steve_jobs_2015
# 20603
# https://www.rottentomatoes.com/m/the_iron_ministry
# 20604
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/trumbo
# 20605
# https://www.rottentomatoes.com/m/love_the_coopers
# 20606
# https://www.rottentomatoes.com/m/bad_hurt
# 20607
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/frankenstein_2015
# 20608
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/my_all_american_2015
# 20609
# https://www.rottentomatoes.com/m/marshland
# 20610
# https://www.rottentomatoes.com/m/stink
# 20611
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/spotlight_2015
# 20612
# https://www.rottentomatoes.com/m/cabin_fever_2016
# 20613
# https://www.rottentomatoes.com/m/criminal_activities
# 20614
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_pack_2016
# 20615
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/estranged_2015
# 20616
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/batman_bad_blood
# 20617
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/we_are_twisted_fing_sister
# 20618
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/hannibal_buress_comedy_camisado
# 20619
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/goosebumps_2015
# 20620
# https://www.rottentomatoes.com/m/jobriath_ad_2012
# 20621
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_new_girlfriend
# 20622
# https://www.rottentomatoes.com/m/suffragette
# 20623
# https://www.rottentomatoes.com/m/bridge_of_spies
# 20624
# ...
# 26612
# https://www.rottentomatoes.com/m/breaking_and_entering
# 26613
# https://www.rottentomatoes.com/m/catch_and_release
# 26614
# https://www.rottentomatoes.com/m/because_i_said_so
# 26615
# https://www.rottentomatoes.com/m/music_and_lyrics
# 26616
# https://www.rottentomatoes.com/m/letters_from_iwo_jima
# 26617
# https://www.rottentomatoes.com/m/painted_veil
# 26618
# https://www.rottentomatoes.com/m/epic_movie
# 26619
# https://www.rottentomatoes.com/m/seraphim_falls
# 26620
# https://www.rottentomatoes.com/m/stomp_the_yard
# 26621
# https://www.rottentomatoes.com/m/alone_with_her
# 26622
# https://www.rottentomatoes.com/m/italian
# 26623
# https://www.rottentomatoes.com/m/fay_grim
# 26624
# https://www.rottentomatoes.com/m/from-other-worlds
# 26625
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/vengeance_is_mine_1979
# 26626
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/last_sin_eater
# 26627
# https://www.rottentomatoes.com/m/ball_of_fire
# 26628
# https://www.rottentomatoes.com/m/american-pastime
# 26629
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1003119-broken_arrow
# 26630
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/prince_of_the_city
# 26631
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1175858-simple_curve
# 26632
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1003436-camelot
# 26633
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/harry_and_the_hendersons
# 26634
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/alice_sweet_alice
# 26635
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/shirley_valentine
# 26636
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/iraq_in_fragments
# 26637
# https://www.rottentomatoes.com/m/1012225-les_miserables
# 26638
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1048301-angels_in_the_outfield
# 26639
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/holy_mountain
# 26640
# https://www.rottentomatoes.com/m/half_nelson
# 26641
# https://www.rottentomatoes.com/m/the_piano_tuner_of_earthquakes
# 26642
# https://www.rottentomatoes.com/m/little_children
# 26643
# https://www.rottentomatoes.com/m/queen
# 26644
# https://www.rottentomatoes.com/m/old_joy
# 26645
# https://www.rottentomatoes.com/m/war_tapes
# 26646
# https://www.rottentomatoes.com/m/1176692-madeinusa
# 26647
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/alpha_dog
# 26648
# https://www.rottentomatoes.com/m/matthew_barney_no_restraint
# 26649
# https://www.rottentomatoes.com/m/dreamgirls
# 26650
# https://www.rottentomatoes.com/m/happily_never_after
# 26651
# https://www.rottentomatoes.com/m/who_the_and_is_jackson_pollock
# 26652
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/a-crude-awakening-the-oil-crash
# 26653
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/diggers
# 26654
# https://www.rottentomatoes.com/m/hitcher
# 26655
# https://www.rottentomatoes.com/m/night_of_the_generals
# 26656
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/caffeine
# 26657
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/fixed_bayonets
# 26658
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1002598-blood_and_sand
# 26659
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/10011854-good_soldier
# 26660
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/little_man_2005
# 26661
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/von_richthofen_and_brown
# 26662
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/rocketman_1997
# 26663
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/brute_force
# 26664
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/la_haine
# 26665
# https://www.rottentomatoes.com/m/1154356-promise
# 26666
# https://www.rottentomatoes.com/m/flannel_pajamas
# 26667
# https://www.rottentomatoes.com/m/the_last_king_of_scotland
# 26668
# https://www.rottentomatoes.com/m/1158918-sleeping_dogs_lie
# 26669
# https://www.rottentomatoes.com/m/le_petit_lieutenant
# 26670
# https://www.rottentomatoes.com/m/el_aura
# 26671
# https://www.rottentomatoes.com/m/forgiving_dr_mengele_2006
# 26672
# https://www.rottentomatoes.com/m/1162559-bobby
# 26673
# https://www.rottentomatoes.com/m/history_boys
# 26674
# https://www.rottentomatoes.com/m/night_at_the_museum
# 26675
# https://www.rottentomatoes.com/m/premium
# 26676
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/deja_vu
# 26677
# https://www.rottentomatoes.com/m/smokin_aces
# 26678
# https://www.rottentomatoes.com/m/1177165-in_debt_we_trust
# 26679
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/notes_on_a_scandal
# 26680
# https://www.rottentomatoes.com/m/freedom_writers
# 26681
# https://www.rottentomatoes.com/m/wilderness_survival_for_girls
# 26682
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/code_name_the_cleaner
# 26683
# https://www.rottentomatoes.com/m/tears_of_the_black_tiger
# 26684
# https://www.rottentomatoes.com/m/fighting_69th
# 26685
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1018994-silent_partner
# 26686
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/phantom_lady
# 26687
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/on_moonlight_bay
# 26688
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/romance_on_the_high_seas
# 26689
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the-war-on-the-war-on-drugs
# 26690
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1070236-convent
# 26691
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/verdict_on_auschwitz_the_frankfurt_trial_1963_1965_2007
# 26692
# https://www.rottentomatoes.com/m/ill_see_you_in_my_dreams_1951
# 26693
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/final_countdown
# 26694
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/solarbabies
# 26695
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the-bridesmaid
# 26696
# https://www.rottentomatoes.com/m/colour-me-kubrick
# 26697
# https://www.rottentomatoes.com/m/candy
# 26698
# https://www.rottentomatoes.com/m/deep_sea_3d
# 26699
# https://www.rottentomatoes.com/m/children_of_men
# 26700
# https://www.rottentomatoes.com/m/death_of_a_president
# 26701
# https://www.rottentomatoes.com/m/happy_feet
# 26702
# https://www.rottentomatoes.com/m/pursuit_of_happyness
# 26703
# https://www.rottentomatoes.com/m/opal_dream
# 26704
# https://www.rottentomatoes.com/m/music_from_the_inside_out_2005
# 26705
# https://www.rottentomatoes.com/m/charlottes_web
# 26706
# https://www.rottentomatoes.com/m/good_shepherd
# 26707
# https://www.rottentomatoes.com/m/turistas
# 26708
# https://www.rottentomatoes.com/m/romantico
# 26709
# https://www.rottentomatoes.com/m/van_wilder_2
# 26710
# https://www.rottentomatoes.com/m/wicked_little_things
# 26711
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/gravedancers
# 26712
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/following_sean_2006
# 26713
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/curse_of_the_golden_flower
# 26714
# https://www.rottentomatoes.com/m/jump_in
# 26715
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/charge_of_the_light_brigade_1936
# 26716
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1021008-tempest
# 26717
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/gentleman_jim
# 26718
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/copying_beethoven
# 26719
# https://www.rottentomatoes.com/m/1016213-peter_pan
# 26720
# https://www.rottentomatoes.com/m/trudell_2004
# 26721
# https://www.rottentomatoes.com/m/revenge_of_the_nerds_ii_nerds_in_paradise
# 26722
# https://www.rottentomatoes.com/m/my_country_my_country
# 26723
# https://www.rottentomatoes.com/m/harsh_times
# 26724
# https://www.rottentomatoes.com/m/everyones_hero
# 26725
# https://www.rottentomatoes.com/m/confetti
# 26726
# https://www.rottentomatoes.com/m/a_little_trip_to_heaven
# 26727
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1202487-book_of_revelation
# 26728
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/nativity_story
# 26729
# https://www.rottentomatoes.com/m/mendy_a_question_of_faith
# 26730
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/favela_rising
# 26731
# https://www.rottentomatoes.com/m/casino_royale
# 26732
# https://www.rottentomatoes.com/m/blood_diamond
# 26733
# https://www.rottentomatoes.com/m/rocky_balboa
# 26734
# https://www.rottentomatoes.com/m/eragon
# 26735
# https://www.rottentomatoes.com/m/1040398-naked_city
# 26736
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_holiday
# 26737
# https://www.rottentomatoes.com/m/in_which_we_serve
# 26738
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/kris-crisis
# 26739
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/guru
# 26740
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/dukes_of_hazzard_the_beginning
# 26741
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/manitou
# 26742
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/sublime
# 26743
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/muriel-1963
# 26744
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/return_of_frank_james
# 26745
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1002407-billy_budd
# 26746
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/confessions_of_a_burning_man
# 26747
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/fall_to_grace
# 26748
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lovewrecked
# 26749
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the-heart-of-the-game
# 26750
# https://www.rottentomatoes.com/m/crossover
# 26751
# https://www.rottentomatoes.com/m/american_hardcore
# 26752
# https://www.rottentomatoes.com/m/tideland
# 26753
# https://www.rottentomatoes.com/m/tenacious_d_in_the_pick_of_destiny
# 26754
# https://www.rottentomatoes.com/m/a_guide_to_recognizing_your_saints
# 26755
# https://www.rottentomatoes.com/m/man_of_the_year
# 26756
# https://www.rottentomatoes.com/m/prestige
# 26757
# https://www.rottentomatoes.com/m/babel
# 26758
# https://www.rottentomatoes.com/m/open_water_2_adrift
# 26759
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/stranger_than_fiction
# 26760
# https://www.rottentomatoes.com/m/la_sierra
# 26761
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/giuliani_time
# 26762
# https://www.rottentomatoes.com/m/flushed_away
# 26763
# https://www.rottentomatoes.com/m/dixie_chicks_shut_up_and_sing
# 26764
# https://www.rottentomatoes.com/m/1170009-conversations_with_god
# 26765
# https://www.rottentomatoes.com/m/return
# 26766
# https://www.rottentomatoes.com/m/zerophilia
# 26767
# https://www.rottentomatoes.com/m/10006856-requiem
# 26768
# https://www.rottentomatoes.com/m/the_gangs_all_here_1943
# 26769
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/good_year
# 26770
# https://www.rottentomatoes.com/m/fast_food_nation
# 26771
# https://www.rottentomatoes.com/m/1159169-for_your_consideration
# 26772
# https://www.rottentomatoes.com/m/captain_horatio_hornblower
# 26773
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/1016756-prisoner_of_zenda
# 26774
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/song_without_end
# 26775
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/up_for_grabs
# 26776
# https://www.rottentomatoes.com/m/going_shopping
# 26777
# https://www.rottentomatoes.com/m/butcher_boy
# 26778
# https://www.rottentomatoes.com/m/infernal_affairs_2
# 26779
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/siones-wedding
# 26780
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/shock_to_the_system_a_donald_strachey_mystery
# 26781
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_quiet
# 26782
# https://www.rottentomatoes.com/m/us_vs_john_lennon
# 26783
# https://www.rottentomatoes.com/m/13_tzameti
# 26784
# https://www.rottentomatoes.com/m/departed
# 26785
# https://www.rottentomatoes.com/m/1158195-marie_antoinette
# 26786
# https://www.rottentomatoes.com/m/cave_of_the_yellow_dog
# 26787
# https://www.rottentomatoes.com/m/mutual_appreciation
# 26788
# https://www.rottentomatoes.com/m/police_story_2
# 26789
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/ginger_and_fred
# 26790
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/so_goes_the_nation
# 26791
# https://www.rottentomatoes.com/m/green_for_danger
# 26792
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/beowulf
# 26793
# https://www.rottentomatoes.com/m/loneliness_of_the_long_distance_runner
# 26794
# https://www.rottentomatoes.com/m/1169498-bridge
# 26795
# https://www.rottentomatoes.com/m/night_of_the_living_dorks
# 26796
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/man_about_town
# 26797
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/black_friday_2005
# 26798
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/cinderella_iii_a_twist_in_time
# 26799
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/david_and_bathsheba
# 26800
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/lebanon_pa
# 26801
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/after_innocence
# 26802
# https://www.rottentomatoes.com/m/crossing_delancey
# 26803
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/10006848-the_motel
# 26804
# https://www.rottentomatoes.com/m/1162724-coastlines
# 26805
# https://www.rottentomatoes.com/m/going_my_way
# 26806
# https://www.rottentomatoes.com/m/world_trade_center
# 26807
# https://www.rottentomatoes.com/m/the_science_of_sleep
# 26808
# https://www.rottentomatoes.com/m/eddie_murphy_delirious
# 26809
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/trust_the_man
# 26810
# https://www.rottentomatoes.com/m/the_efficiency_expert
# 26811
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/riding_alone_for_thousands_of_miles
# 26812
# https://www.rottentomatoes.com/m/hollywoodland
# 26813
# https://www.rottentomatoes.com/m/flyboys
# 26814
# https://www.rottentomatoes.com/m/open_season
# 26815
# https://www.rottentomatoes.com/m/facing_the_giants
# 26816
# https://www.rottentomatoes.com/m/grudge_2
# 26817
# https://www.rottentomatoes.com/m/marine
# 26818
# https://www.rottentomatoes.com/m/flags_of_our_fathers
# 26819
# https://www.rottentomatoes.com/m/flicka
# 26820
# https://www.rottentomatoes.com/m/catch_a_fire
# 26821
# https://www.rottentomatoes.com/m/boynton_beach_club
# 26822
# https://www.rottentomatoes.com/m/1166226-red_doors
# 26823
# https://www.rottentomatoes.com/m/looker
# 26824
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/en_soap
# 26825
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/clock
# 26826
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/here_comes_mr_jordan
# 26827
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/band_of_angels
# 26828
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/summer_place
# 26829
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/charulata
# 26830
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/the_arrangement
# 26831
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/madame_curie
# 26832
# something wrong with critic_consensus
# https://www.rottentomatoes.com/m/blume_in_love
# 26833
# something wrong with critic_consensus

# %%
# page = requests.get("https://www.rottentomatoes.com/m/bobby_fischer_against_the_world")
# soup=bs(page.text)
# movie_name = soup.find('div',{'class':'mop-ratings-wrap score_panel js-mop-ratings-wrap'})
# movie_name = soup.findAll('h1',{'class':'mop-ratings-wrap__title mop-ratings-wrap__title--top'})[0].get_text()

# %%
# movies_1400_data = scrape_rotten(movie_url_genre)
movies_1400_data = movies_1400_data.replace('\n','', regex=True)
movies_1400_data = movies_1400_data.replace('  ','', regex=True)
movies_1400_data.to_csv("movies_1400_data.csv", index=False)
movies_1400_data.to_pickle("movies_1400_data.pkl")

# %% [markdown]
# ### Movie name and consensus

# %%
page = requests.get("https://www.rottentomatoes.com/m/seven_samurai_1956")
soup=bs(page.text)


movie_name = soup.find('div',{'class':'mop-ratings-wrap score_panel js-mop-ratings-wrap'})
movie_name = soup.findAll('h1',{'class':'mop-ratings-wrap__title mop-ratings-wrap__title--top'})[0].get_text()
critic_consensus = soup.findAll('p',{'class':'mop-ratings-wrap__text mop-ratings-wrap__text--concensus'})[0].get_text()

# %%
movie_name
# Out:
# 'Seven Samurai (Shichinin no Samurai)'

# %%
critic_consensus
# Out:
# "Arguably Akira Kurosawa's masterpiece, The Seven Samurai is an epic adventure classic with an engrossing story, memorable characters, and stunning action sequences that make it one of the most influential films ever made."

# %% [markdown]
# ## Ratings

# %%
critic = soup.find('div',{'class':'mop-ratings-wrap__half'})

# %%
try:
    critic_score = critic.find('span',{'class':'mop-ratings-wrap__percentage'}).get_text()
    print(critic_score)
except AttributeError:
    critic_score = np.NaN
# Out:
#                     100%

# %%
num_critics = critic.find('small',{'class':'mop-ratings-wrap__text--small'}).get_text()
num_critics.replace('\n','')
# Out:
# '                            64                    '

# %%
audience = soup.find('div',{'class':'mop-ratings-wrap__half audience-score'})
try:
    audience_score = audience.find('span',{'class':'mop-ratings-wrap__percentage'}).get_text()
    print(audience_score)
except AttributeError:
    audience_score = np.NaN
# Out:
#                     97%

# %%
num_audience = audience.find('strong',{'class':'mop-ratings-wrap__text--small'}).get_text()
num_audience
# Out:
# 'User Ratings: 90,992'

# %% [markdown]
# ### Movie Info

# %%
tables = soup.find('div',{'class':'panel-body content_body'})
synopsis = tables.findAll('div',{'class':'movie_synopsis clamp clamp-6 js-clamp'})[0].get_text()
synopsis.replace('\n','')
# Out:
# "                Akira Kurosawa's epic tale concerns honor and duty during a time when the old traditional order is breaking down. The film opens with master samurai Kambei (Takashi Shimura) posing as a monk to save a kidnapped farmer's child. Impressed by his selflessness and bravery, a group of farmers begs him to defend their terrorized village from bandits. Kambei agrees, although there is no material gain or honor to be had in the endeavor. Soon he attracts a pair of followers: a young samurai named Katsushiro (Isao Kimura), who quickly becomes Kambei's disciple, and boisterous Kikuchiyo (Toshiro Mifune), who poses as a samurai but is later revealed to be the son of a farmer. Kambei assembles four other samurais, including Kyuzo (Seiji Miyaguchi), a master swordsman, to round out the group. Together they consolidate the village's defenses and shape the villagers into a militia, while the bandits loom menacingly nearby. Soon raids and counter-raids build to a final bloody heart-wrenching battle. ~ Jonathan Crow, Rovi            "

# %%
pg = tables.find('div',{'class':'meta-value'}).get_text()
pg.replace('\n','')
# Out:
# 'G                    '

# %%
synopsis = tables.findAll('li',{'class':'meta-row clearfix'})
genre = synopsis[1].find('div',{'class':'meta-value'}).get_text()
genre.replace('\n','')
# Out:
# '                                                Action & Adventure,                                                 Art House & International,                                                 Classics,                                                 Drama                                            '

# %%
directors = synopsis[2].findAll('div',{'class':'meta-value'})[0].get_text()
directors.replace('\n','')
# Out:
# 'Akira Kurosawa'

# %%
written_by = synopsis[3].findAll('div',{'class':'meta-value'})[0].get_text()
written_by.replace('\n','')
# Out:
# 'Akira Kurosawa,                                                 Shinobu Hashimoto,                                                 Hideo Oguni'

# %%
release_date = synopsis[4].findAll('div',{'class':'meta-value'})[0].get_text()
release_date.replace('\n','')
# Out:
# 'Nov 19, 1956                        \xa0wide'

# %%
run_time = synopsis[7].findAll('div',{'class':'meta-value'})[0].get_text()
run_time
# Out:
# '\n                        Columbia Pictures\n                    '

# %% [markdown]
# dict_data = {}
#
# for i in range(12):
#     try:
#         ii = synopsis[i].findAll('div',{'class':'meta-label subtle'})[0].get_text()
#         dict_data[ii] = synopsis[i].find('div',{'class':'meta-value'}).get_text()
#     except:
#         continue

# %%
try:
    studio = synopsis[8].findAll('div',{'class':'meta-value'})[0].get_text()

except IndexError:
    studio = np.NaN
print(studio)
# Out:
# nan

# %% [markdown]
# ## Cast

# %%
def list_celeb_names(all_celebrities):
    top_5_celeb_names = []
    try:
        for i in range(5):
            top_5_celeb_names.append(all_celebrities[i].attrs['href'][11:])
    except IndexError:
        continue
    return top_5_celeb_names

# %%
cast = soup.find('div',{'class':'castSection'})
try :
    all_celebs = cast.findAll('a',{'class':'pull-left'})
    top_5_celeb_names = list_celeb_names(all_celebs)
#     print(top_5_celeb_names)
except AttributeError:
    pass
top_5_celeb_names = ", ".join(top_5_celeb_names)
top_5_celeb_names

# %% [markdown]
# ## Critics Review

# %%
def critic_line_url(critic_lines):
    url =[]
    critic_line =[]
    for i in range(20):
        try:
            url.append(critic_lines[i].attrs['cite'])
            critic_line.append(critic_lines[i].get_text())
        except:
            continue
    return critic_line, url

# %%
# critic_review = soup.find('section',{'class':'panel panel-rt panel-box'})
critic_lines = soup.findAll('div',{'class':'panel-body content_body'})[3]
critic_lines = critic_lines.findAll('blockquote',{'class':'media-body quote_bubble__quote'})
critic_line, critic_url = critic_line_url(critic_lines)
critic_line, critic_url = ", ".join(critic_line), ", ".join(critic_url)
critic_url

# %% [markdown]
# ## Audiences Review

# %%
def audience_line(audience_review):
    audience_line =[]
    for i in range(10):
        try:
            audience_line.append(audience_review.findAll('div',{'class':'mop-audience-reviews__review--comment clamp clamp-4 js-clamp'})[i].get_text())
        except IndexError:
            continue
    return audience_line

# %%
audience_review = soup.find('ul',{'class':'mop-audience-reviews__reviews-wrap clearfix'})
audience_lines = audience_line(audience_review)
audience_review = "".join(audience_lines)
audience_review

# %% [markdown]
# ## Quotes

# %%
quotes_url = soup.findAll('div',{'class':'panel-body content_body'})[4]
quotes_url = quotes_url.find('a',{'class':'unstyled articleLink fr'}).attrs['href']
quotes_url = 'https://www.rottentomatoes.com' + quotes_url
quotes_page = requests.get(quotes_url)
quotes_page=bs(quotes_page.text)

# %%
quotes_lines = quotes_page.findAll('div',{'class':'panel-body content_body'})[1]
# quotes_lines.findAll('span',{'class':'bold quote_actor'})
quotes_lines = quotes_lines.findAll('span')

# %%
quote_lines = quotes_lines[1::2]
# [word for word in re.split("\W+",quote_lines) if word.lower() not in ['<span>']]
cleaned_quotes = []
for line in quote_lines:
    try:
        line = str(line).replace('\n','')
        cleaned_quotes.append(re.search('<span>(.*)</span>',line).group(1))
    except:
        continue

quotes = "".join(cleaned_quotes)
# quotes

# %%
# for i in list(quotes_lines):
#     items = re.findall("bold quote_actor.*$",str(i),re.MULTILINE)
#     print(items)

# %%
# ,'num_critics','audience_score','num_audience',
#                           'synopsis','pg','genre','directors','written_by','release_date',
#                            'run_time','studio','top_5_celeb_names', 'critic_line', 'critic_url',
#                             'audience_review', 'quotes'

# %%
df=pd.DataFrame()
df['critic_score'] = [critic_score]
df['audience_score'] = [audience_score]
df['pg'] = pg
df['genre'] = genre
df['directors'] = directors
df['written_by'] = written_by
df['release_date'] = release_date
df['run_time'] = run_time
df['studio'] = studio
df['top_5_celeb_names'] = top_5_celeb_names
df['critic_line'] = critic_line
df['critic_url'] = critic_url
df['audience_review'] = audience_review
df['quotes'] = quotes

# %%
df
